# %%
# Clone PaddleDetection
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# %cd PaddleDetection

# Install dependencies
# !pip install -r requirements.txt
# !pip install paddlepaddle==2.5.2 -f https://www.paddlepaddle.org.cn/whl/pip/windows.html
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 258348, done.
# remote: Counting objects: 100% (780/780), done.
# remote: Compressing objects: 100% (410/410), done.
# remote: Total 258348 (delta 597), reused 395 (delta 370), pack-reused 257568 (from 4)
# Receiving objects: 100% (258348/258348), 422.29 MiB | 22.86 MiB/s, done.
# Resolving deltas: 100% (210488/210488), done.
# /content/PaddleDetection
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 86.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 98.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 12.1 MB/s eta 0:00:00
# ...

# %%
# Download PicoDet medium (PicoDet_m_416_coco_lcnet) pretrained model
# !mkdir -p output_inference/picodet_m_416_coco_lcnet
# !wget https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams -O output_inference/picodet_m_416_coco_lcnet/model.pdparams
# Out:
# --2025-06-20 18:45:31--  https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 103.235.47.176, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14056806 (13M) [application/octet-stream]
# Saving to: ‘output_inference/picodet_m_416_coco_lcnet/model.pdparams’
#
# output_inference/pi 100%[===================>]  13.41M  3.46MB/s    in 20s
#
# 2025-06-20 18:45:54 (678 KB/s) - ‘output_inference/picodet_m_416_coco_lcnet/model.pdparams’ saved [14056806/14056806]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79b755f3-880d-4f53-9788-fbb9c3376c74" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79b755f3-880d-4f53-9788-fbb9c3376c74">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Export the model for inference (CPU mode)
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=output_inference/picodet_m_416_coco_lcnet/model.pdparams,use_gpu=false \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleDetection/tools/export_model.py", line 31, in <module>
#     from ppdet.core.workspace import load_config, merge_config
#   File "/content/PaddleDetection/ppdet/__init__.py", line 15, in <module>
#     from . import (core, data, engine, modeling, model_zoo, optimizer, metrics,
#   File "/content/PaddleDetection/ppdet/data/__init__.py", line 16, in <module>
#     from . import transform
#   File "/content/PaddleDetection/ppdet/data/transform/__init__.py", line 15, in <module>
#     from . import operators
#   File "/content/PaddleDetection/ppdet/data/transform/operators.py", line 57, in <module>
#     from ppdet.modeling.keypoint_utils import get_affine_transform, affine_transform
#   File "/content/PaddleDetection/ppdet/modeling/__init__.py", line 23, in <module>
#     from . import heads
#   File "/content/PaddleDetection/ppdet/modeling/heads/__init__.py", line 17, in <module>
#     from . import yolo_head
# ...

# %%
# Remove any older paddlepaddle version
# !pip uninstall -y paddlepaddle

# Install compatible PaddlePaddle version (CPU version)
# !pip install paddlepaddle==2.5.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Found existing installation: paddlepaddle 2.5.2
# Uninstalling paddlepaddle-2.5.2:
#   Successfully uninstalled paddlepaddle-2.5.2
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 MB 5.0 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall -y paddlepaddle paddlepaddle-gpu
# Out:
# Found existing installation: paddlepaddle 2.5.2
# Uninstalling paddlepaddle-2.5.2:
#   Successfully uninstalled paddlepaddle-2.5.2
# WARNING: Skipping paddlepaddle-gpu as it is not installed.

# %%
# !pip install paddlepaddle==2.5.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/0c/cd/947dada3e7e58cecd165f90ad2790e37610d79ec0a2ad3d678ef4a989c3c/paddlepaddle-2.5.2-cp311-cp311-manylinux1_x86_64.whl (126.5 MB)
# ...

# %%
import paddle
print(paddle.__version__)
# Out:
# 2.5.2

# %%
# %cd /content/PaddleDetection
# Out:
# /content/PaddleDetection

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=output_inference/picodet_m_416_coco_lcnet/model.pdparams,use_gpu=false \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleDetection/tools/export_model.py", line 31, in <module>
#     from ppdet.core.workspace import load_config, merge_config
#   File "/content/PaddleDetection/ppdet/__init__.py", line 15, in <module>
#     from . import (core, data, engine, modeling, model_zoo, optimizer, metrics,
#   File "/content/PaddleDetection/ppdet/data/__init__.py", line 16, in <module>
#     from . import transform
#   File "/content/PaddleDetection/ppdet/data/transform/__init__.py", line 15, in <module>
#     from . import operators
#   File "/content/PaddleDetection/ppdet/data/transform/operators.py", line 57, in <module>
#     from ppdet.modeling.keypoint_utils import get_affine_transform, affine_transform
#   File "/content/PaddleDetection/ppdet/modeling/__init__.py", line 23, in <module>
#     from . import heads
#   File "/content/PaddleDetection/ppdet/modeling/heads/__init__.py", line 17, in <module>
#     from . import yolo_head
# ...

# %%
# !pip uninstall -y paddlepaddle
# Out:
# Found existing installation: paddlepaddle 2.5.2
# Uninstalling paddlepaddle-2.5.2:
#   Successfully uninstalled paddlepaddle-2.5.2

# %%
# !pip install paddlepaddle==2.6.1 -f https://www.paddlepaddle.org.cn/whl/paddle/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/paddle/avx/stable.html
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 5.8 MB/s eta 0:00:00
# ...

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:00:15] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# ...
# [06/20 19:00:15] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/' configs/picodet/picodet_s_320_coco_lcnet.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams,use_gpu=False \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:01:20] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# ...
# [06/20 19:01:20] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !pip uninstall -y paddlepaddle paddlepaddle-gpu
# Out:
# WARNING: Skipping paddlepaddle as it is not installed.
# WARNING: Skipping paddlepaddle-gpu as it is not installed.

# %%
# !pip install paddlepaddle-gpu==2.6.1 -f https://www.paddlepaddle.org.cn/whl/mkl/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/mkl/avx/stable.html
# ...

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# %cd PaddleDetection
# Out:
# fatal: destination path 'PaddleDetection' already exists and is not an empty directory.
# /content/PaddleDetection

# %%
# !pip install -r requirements.txt

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
# ...

# %%
# !mkdir -p output_inference/picodet_s_320_coco_lcnet
# !wget https://paddledet.bj.bcebos.com/models/picodet_s_320_coco_lcnet.pdparams -O output_inference/picodet_s_320_coco_lcnet/model.pdparams
# Out:
# --2025-06-20 19:09:06--  https://paddledet.bj.bcebos.com/models/picodet_s_320_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 103.235.47.176, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4868498 (4.6M) [application/octet-stream]
# Saving to: ‘output_inference/picodet_s_320_coco_lcnet/model.pdparams’
#
# output_inference/pi 100%[===================>]   4.64M  6.21MB/s    in 0.7s
#
# 2025-06-20 19:09:08 (6.21 MB/s) - ‘output_inference/picodet_s_320_coco_lcnet/model.pdparams’ saved [4868498/4868498]

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:09:28] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:09:29] ppdet.utils.checkpoint INFO: Finish loading model weights: output_inference/picodet_s_320_coco_lcnet/model.pdparams
# [06/20 19:09:33] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [06/20 19:09:33] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [06/20 19:09:33] ppdet.engine INFO: Export inference config file to output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet/infer_cfg.yml
# [06/20 19:09:33] ppdet.engine INFO: Skipping import of the encryption module.
# I0620 19:09:33.642807  3178 program_interpreter.cc:212] New Executor is Running.
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_s_320_coco_lcnet \
  --video_file=/content/short-video.mp4 \
  --device=GPU \
  --output_dir=/content/output/
# Out:
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# collect_trt_shape_info: False
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: None
# match_metric: ios
# match_threshold: 0.6
# model_dir: output_inference/picodet_s_320_coco_lcnet
# output_dir: /content/output/
# overlap_ratio: [0.25, 0.25]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: False
# slice_size: [640, 640]
# task_type: Detection
# threshold: 0.5
# tracker_config: None
# trt_calib_mode: False
# trt_max_shape: 1280
# trt_min_shape: 1
# trt_opt_shape: 640
# tuned_trt_shape_file: shape_range_info.pbtxt
# use_coco_category: False
# use_dark: True
# use_fd_format: False
# use_gpu: False
# ...

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:13:09] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:13:10] ppdet.utils.checkpoint INFO: Finish loading model weights: output_inference/picodet_s_320_coco_lcnet/model.pdparams
# [06/20 19:13:12] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [06/20 19:13:12] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [06/20 19:13:12] ppdet.engine INFO: Export inference config file to output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet/infer_cfg.yml
# [06/20 19:13:12] ppdet.engine INFO: Skipping import of the encryption module.
# I0620 19:13:13.588697  4142 program_interpreter.cc:212] New Executor is Running.
# ...

# %%
# !ls output_inference/picodet_s_320_coco_lcnet
# Out:
# model.pdparams	picodet_s_320_coco_lcnet

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:15:09] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:15:09] ppdet.utils.checkpoint INFO: Finish loading model weights: output_inference/picodet_s_320_coco_lcnet/model.pdparams
# [06/20 19:15:12] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [06/20 19:15:12] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [06/20 19:15:12] ppdet.engine INFO: Export inference config file to output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet/infer_cfg.yml
# [06/20 19:15:12] ppdet.engine INFO: Skipping import of the encryption module.
# I0620 19:15:13.019739  4646 program_interpreter.cc:212] New Executor is Running.
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet \
  --video_file=/content/video-3.mp4 \
  --device=CPU \
  --output_dir=/content/output/
# Out:
# python3: can't open file '/content/deploy/python/infer.py': [Errno 2] No such file or directory

# %%
# %cd /content/PaddleDetection
# Out:
# [Errno 2] No such file or directory: '/content/PaddleDetection'
# /content

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 258348, done.
# remote: Counting objects: 100% (789/789), done.
# remote: Compressing objects: 100% (416/416), done.
# remote: Total 258348 (delta 605), reused 398 (delta 373), pack-reused 257559 (from 4)
# Receiving objects: 100% (258348/258348), 422.29 MiB | 23.22 MiB/s, done.
# Resolving deltas: 100% (210487/210487), done.

# %%
# %cd PaddleDetection
# Out:
# /content/PaddleDetection

# %%
# !pip install paddlepaddle -i https://mirror.baidu.com/pypi/simple
# Out:
# Looking in indexes: https://mirror.baidu.com/pypi/simple
# ERROR: Could not find a version that satisfies the requirement paddlepaddle (from versions: none)
# ERROR: No matching distribution found for paddlepaddle

# %%
# !pip install paddlepaddle==2.6.1 -f https://www.paddlepaddle.org.cn/whl/paddle/linux/mkl/avx/stable.html
# Out:
# Looking in links: https://www.paddlepaddle.org.cn/whl/paddle/linux/mkl/avx/stable.html
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=/content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet \
  --video_file=/content/short-video.mp4 \
  --device=CPU \
  --output_dir=/content/output/
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleDetection/deploy/python/infer.py", line 36, in <module>
#     from preprocess import preprocess, Resize, NormalizeImage, Permute, PadStride, LetterBoxResize, WarpAffine, Pad, decode_image, CULaneResize
#   File "/content/PaddleDetection/deploy/python/preprocess.py", line 17, in <module>
#     import imgaug.augmenters as iaa
# ModuleNotFoundError: No module named 'imgaug'

# %%
# !pip install imgaug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 10.5 MB/s eta 0:00:00
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=/content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet \
  --video_file=/content/short-video.mp4 \
  --device=CPU \
  --output_dir=/content/output/
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleDetection/deploy/python/infer.py", line 36, in <module>
#     from preprocess import preprocess, Resize, NormalizeImage, Permute, PadStride, LetterBoxResize, WarpAffine, Pad, decode_image, CULaneResize
#   File "/content/PaddleDetection/deploy/python/preprocess.py", line 17, in <module>
#     import imgaug.augmenters as iaa
#   File "/usr/local/lib/python3.11/dist-packages/imgaug/__init__.py", line 7, in <module>
#     from imgaug.imgaug import *  # pylint: disable=redefined-builtin
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/imgaug/imgaug.py", line 45, in <module>
#     NP_FLOAT_TYPES = set(np.sctypes["float"])
#                          ^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/__init__.py", line 397, in __getattr__
#     raise AttributeError(
# ...

# %%
# !pip install numpy==1.24.3 --force-reinstall
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 82.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pymc 5.23.0 requires numpy>=1.25.0, but you have numpy 1.24.3 which is incompatible.
# albucore 0.0.24 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 1.24.3 which is incompatible.
# xarray-einstats 0.9.0 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# albumentations 2.0.8 requires numpy>=1.24.4, but you have numpy 1.24.3 which is incompatible.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.24.3 which is incompatible.
# ...

# %%
import os; os.kill(os.getpid(), 9)

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# %cd PaddleDetection
# Out:
# fatal: destination path 'PaddleDetection' already exists and is not an empty directory.
# /content/PaddleDetection

# %%
# !pip install -r requirements.txt
# !pip install paddlepaddle==2.6.1 -f https://www.paddlepaddle.org.cn/whl/paddle/linux/mkl/avx/stable.html
# !python setup.py install
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 55.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.8/344.8 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 81.6 MB/s eta 0:00:00
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1302 sha256=82f73c3719a48a31903943abe9a3ecacc0688b65fa1d407c262cf6a80eeadf79
#   Stored in directory: /root/.cache/pip/wheels/f0/c8/5e/d8ffba9c1c0398e9ab1e97b2b237b46e614033b514b7f7e92a
# Successfully built sklearn
# ...
#   Attempting uninstall: opencv-python
# ...

# %%
import numpy as np
print(np.__version__)  # should print 1.24.3
# Out:
# 1.24.3

# %%
# !python deploy/python/infer.py \
  --model_dir=/content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet \
  --video_file=/content/short-video.mp4 \
  --device=CPU \
  --output_dir=/content/output/
# Out:
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# collect_trt_shape_info: False
# combine_method: nms
# cpu_threads: 1
# device: CPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: None
# match_metric: ios
# match_threshold: 0.6
# model_dir: /content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet
# output_dir: /content/output/
# overlap_ratio: [0.25, 0.25]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: False
# slice_size: [640, 640]
# task_type: Detection
# threshold: 0.5
# tracker_config: None
# trt_calib_mode: False
# trt_max_shape: 1280
# trt_min_shape: 1
# trt_opt_shape: 640
# tuned_trt_shape_file: shape_range_info.pbtxt
# use_coco_category: False
# use_dark: True
# use_fd_format: False
# ...

# %%
# !ls /content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet
# Out:
# ls: cannot access '/content/output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet': No such file or directory

# %%
# !ls /content/output_inference/
# Out:
# ls: cannot access '/content/output_inference/': No such file or directory

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/picodet_s_320_coco_lcnet.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams,use_gpu=False \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:45:39] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:45:39] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !grep use_gpu configs/picodet/picodet_s_320_coco_lcnet.yml

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/_base_/picodet_v2.yml
# Out:
# sed: can't read configs/_base_/picodet_v2.yml: No such file or directory

# %%
# !grep "_base_" configs/picodet/picodet_s_320_coco_lcnet.yml
# Out:
#   '_base_/picodet_v2.yml',
#   '_base_/optimizer_300e.yml',
#   '_base_/picodet_320_reader.yml',

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/_base_/picodet_v2.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/_base_/optimizer_300e.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/_base_/picodet_320_reader.yml
# Out:
# sed: can't read configs/_base_/picodet_v2.yml: No such file or directory
# sed: can't read configs/_base_/optimizer_300e.yml: No such file or directory
# sed: can't read configs/_base_/picodet_320_reader.yml: No such file or directory

# %%
# !find configs -name "*.yml" | grep -E "picodet_v2|optimizer_300e|picodet_320_reader"
# Out:
# configs/ppyoloe/_base_/optimizer_300e.yml
# configs/picodet/legacy_model/pruner/optimizer_300e_pruner.yml
# configs/picodet/legacy_model/_base_/picodet_320_reader.yml
# configs/picodet/legacy_model/_base_/optimizer_300e.yml
# configs/picodet/_base_/picodet_320_reader.yml
# configs/picodet/_base_/picodet_v2.yml
# configs/picodet/_base_/optimizer_300e.yml
# configs/yolox/_base_/optimizer_300e.yml

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/picodet_v2.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/optimizer_300e.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/picodet_320_reader.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:50:38] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:50:38] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !grep -r "use_gpu" configs/picodet/
# Out:
# configs/picodet/application/pedestrian_detection/picodet_s_192_lcnet_pedestrian.yml:use_gpu: true
# configs/picodet/application/pedestrian_detection/picodet_s_320_lcnet_pedestrian.yml:use_gpu: true
# configs/picodet/legacy_model/application/pedestrian_detection/picodet_s_320_pedestrian.yml:use_gpu: true
# configs/picodet/legacy_model/application/pedestrian_detection/picodet_s_192_pedestrian.yml:use_gpu: true

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output_inference/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:52:28] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:52:28] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !echo "use_gpu: false" >> configs/picodet/picodet_s_320_coco_lcnet.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output/picodet_s_320_coco_lcnet/model.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:55:27] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# Traceback (most recent call last):
#   File "/content/PaddleDetection/tools/export_model.py", line 122, in <module>
#     main()
#   File "/content/PaddleDetection/tools/export_model.py", line 118, in main
#     run(FLAGS, cfg)
#   File "/content/PaddleDetection/tools/export_model.py", line 77, in run
#     trainer.load_weights(cfg.weights)
#   File "/content/PaddleDetection/ppdet/engine/trainer.py", line 474, in load_weights
#     load_pretrain_weight(self.model, weights, ARSL_eval)
#   File "/content/PaddleDetection/ppdet/utils/checkpoint.py", line 250, in load_pretrain_weight
#     raise ValueError("Model pretrain path `{}` does not exists. "
# ValueError: Model pretrain path `output/picodet_s_320_coco_lcnet/model` does not exists. If you don't want to load pretrain model, please delete `pretrain_weights` field in config file.

# %%
# !wget https://paddledet.bj.bcebos.com/models/picodet_s_320_coco_lcnet.pdparams -P output/
# Out:
# --2025-06-20 19:56:17--  https://paddledet.bj.bcebos.com/models/picodet_s_320_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 103.235.47.176, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4868498 (4.6M) [application/octet-stream]
# Saving to: ‘output/picodet_s_320_coco_lcnet.pdparams’
#
# picodet_s_320_coco_ 100%[===================>]   4.64M  11.3MB/s    in 0.4s
#
# 2025-06-20 19:56:18 (11.3 MB/s) - ‘output/picodet_s_320_coco_lcnet.pdparams’ saved [4868498/4868498]

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_s_320_coco_lcnet.yml \
  -o weights=output/picodet_s_320_coco_lcnet.pdparams \
  --output_dir=output_inference/picodet_s_320_coco_lcnet
# Out:
# [06/20 19:56:41] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# [06/20 19:56:42] ppdet.utils.checkpoint INFO: Finish loading model weights: output/picodet_s_320_coco_lcnet.pdparams
# [06/20 19:56:46] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [06/20 19:56:46] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [06/20 19:56:46] ppdet.engine INFO: Export inference config file to output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet/infer_cfg.yml
# [06/20 19:56:46] ppdet.engine INFO: Skipping import of the encryption module.
# I0620 19:56:47.444864  9458 program_interpreter.cc:212] New Executor is Running.
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_s_320_coco_lcnet/picodet_s_320_coco_lcnet \
  --video_file=/content/video-3.mp4 \
  --device=CPU \
  --output_dir=/content/output/
# Out:
# Streaming output truncated to the last 5000 lines.
# Test iter 0
# class_id:56, confidence:0.5503, left_top:[1142.58,666.11],right_bottom:[1915.63,1079.43]
# class_id:58, confidence:0.5032, left_top:[328.65,455.51],right_bottom:[503.41,725.39]
# detect frame: 4069
# Test iter 0
# class_id:56, confidence:0.5919, left_top:[1140.05,666.48],right_bottom:[1912.39,1079.50]
# class_id:58, confidence:0.5436, left_top:[328.14,455.11],right_bottom:[503.72,725.04]
# detect frame: 4070
# Test iter 0
# class_id:56, confidence:0.5922, left_top:[1140.17,666.33],right_bottom:[1913.61,1079.53]
# class_id:58, confidence:0.5495, left_top:[328.52,454.99],right_bottom:[504.29,724.95]
# detect frame: 4071
# Test iter 0
# detect frame: 4072
# Test iter 0
# detect frame: 4073
# Test iter 0
# class_id:0, confidence:0.5204, left_top:[550.93,811.34],right_bottom:[957.93,1081.66]
# class_id:58, confidence:0.5655, left_top:[325.48,455.26],right_bottom:[503.01,725.52]
# detect frame: 4074
# Test iter 0
# ...

# %%
# !ls output_inference/picodet_s_320_coco_lcnet
# Out:
# model.pdparams	picodet_s_320_coco_lcnet

# %%
import os; os.kill(os.getpid(), 9)

# %%
# !wget https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams -P pretrained/
# Out:
# --2025-06-23 06:41:34--  https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 113.137.57.33, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|113.137.57.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14056806 (13M) [application/octet-stream]
# Saving to: ‘pretrained/picodet_m_416_coco_lcnet.pdparams’
#
# picodet_m_416_coco_ 100%[===================>]  13.41M  3.80MB/s    in 16s
#
# 2025-06-23 06:41:52 (852 KB/s) - ‘pretrained/picodet_m_416_coco_lcnet.pdparams’ saved [14056806/14056806]

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# Out:
# Cloning into 'PaddleDetection'...
# remote: Enumerating objects: 258348, done.
# remote: Counting objects: 100% (780/780), done.
# remote: Compressing objects: 100% (410/410), done.
# remote: Total 258348 (delta 597), reused 395 (delta 370), pack-reused 257568 (from 4)
# Receiving objects: 100% (258348/258348), 422.29 MiB | 24.42 MiB/s, done.
# Resolving deltas: 100% (210488/210488), done.

# %%
# %cd PaddleDetection
# Out:
# /content/PaddleDetection

# %%
# !pip install -r requirements.txt

# %%
import os
os.kill(os.getpid(), 9)

# %%
# !pip install paddlepaddle -U

# %%
# !wget https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams -P pretrained/
# Out:
# --2025-06-23 06:48:54--  https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 103.235.47.176, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|103.235.47.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14056806 (13M) [application/octet-stream]
# Saving to: ‘pretrained/picodet_m_416_coco_lcnet.pdparams.2’
#
# picodet_m_416_coco_ 100%[===================>]  13.41M  3.36MB/s    in 20s
#
# 2025-06-23 06:49:16 (685 KB/s) - ‘pretrained/picodet_m_416_coco_lcnet.pdparams.2’ saved [14056806/14056806]

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=pretrained/picodet_m_416_coco_lcnet.pdparams \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# python3: can't open file '/content/tools/export_model.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/PaddlePaddle/PaddleDetection.git
# Out:
# fatal: destination path 'PaddleDetection' already exists and is not an empty directory.

# %%
# %cd PaddleDetection
# Out:
# /content/PaddleDetection

# %%
# !wget https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams -P pretrained/
# Out:
# --2025-06-23 06:51:16--  https://paddledet.bj.bcebos.com/models/picodet_m_416_coco_lcnet.pdparams
# Resolving paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)... 113.137.57.33, 2402:2b40:7000:628:0:ff:b0e8:88da
# Connecting to paddledet.bj.bcebos.com (paddledet.bj.bcebos.com)|113.137.57.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14056806 (13M) [application/octet-stream]
# Saving to: ‘pretrained/picodet_m_416_coco_lcnet.pdparams’
#
# picodet_m_416_coco_ 100%[===================>]  13.41M  3.47MB/s    in 18s
#
# 2025-06-23 06:51:37 (769 KB/s) - ‘pretrained/picodet_m_416_coco_lcnet.pdparams’ saved [14056806/14056806]

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/picodet_m_416_coco_lcnet.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=pretrained/picodet_m_416_coco_lcnet.pdparams,use_gpu=False \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# [06/23 06:53:34] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# ...
# [06/23 06:53:34] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/picodet_m_416_coco_lcnet.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=pretrained/picodet_m_416_coco_lcnet.pdparams \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# [06/23 06:55:06] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# ...
# [06/23 06:55:06] ppdet.utils.check ERROR: Config use_gpu cannot be set as true while you are using paddlepaddle cpu version !
# Please try:
# 	1. Install paddlepaddle-gpu to run model on GPU
# 	2. Set use_gpu as false in config file to run model on CPU

# %%
# !grep "use_gpu" configs/picodet/picodet_m_416_coco_lcnet.yml

# %%
# !sed -i '/use_gpu:/c\use_gpu: false' configs/picodet/picodet_m_416_coco_lcnet.yml

# %%
# !grep "use_gpu" configs/picodet/picodet_m_416_coco_lcnet.yml

# %%
# !cat configs/picodet/picodet_m_416_coco_lcnet.yml
# Out:
# _BASE_: [
#   '../datasets/coco_detection.yml',
#   '../runtime.yml',
#   '_base_/picodet_v2.yml',
#   '_base_/optimizer_300e.yml',
#   '_base_/picodet_416_reader.yml',
# ]
#
# weights: output/picodet_m_416_coco/best_model
# find_unused_parameters: True
# use_ema: true
# epoch: 250
# snapshot_epoch: 10
#
# TrainReader:
#   batch_size: 48
#
# LearningRate:
#   base_lr: 0.24
#   schedulers:
#   - name: CosineDecay
#     max_epochs: 300
#   - name: LinearWarmup
#     start_factor: 0.1
#     steps: 300

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/picodet_v2.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/optimizer_300e.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/picodet/_base_/picodet_416_reader.yml

# %%
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/datasets/coco_detection.yml
# !sed -i 's/use_gpu: true/use_gpu: false/g' configs/runtime.yml

# %%
# !python tools/export_model.py \
  -c configs/picodet/picodet_m_416_coco_lcnet.yml \
  -o weights=pretrained/picodet_m_416_coco_lcnet.pdparams \
  --output_dir=output_inference/picodet_m_416_coco_lcnet
# Out:
# [06/23 07:00:14] ppdet.utils.checkpoint INFO: Skipping import of the encryption module.
# ...
# [06/23 07:00:15] ppdet.utils.checkpoint INFO: Finish loading model weights: pretrained/picodet_m_416_coco_lcnet.pdparams
# [06/23 07:00:21] ppdet.data.source.category WARNING: anno_file 'dataset/coco/annotations/instances_val2017.json' is None or not set or not exist, please recheck TrainDataset/EvalDataset/TestDataset.anno_path, otherwise the default categories will be used by metric_type.
# [06/23 07:00:21] ppdet.data.source.category WARNING: metric_type: COCO, load default categories of COCO.
# [06/23 07:00:21] ppdet.engine INFO: Export inference config file to output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet/infer_cfg.yml
# [06/23 07:00:21] ppdet.engine INFO: Skipping import of the encryption module.
# I0623 07:00:28.167317  5824 program_interpreter.cc:243] New Executor is Running.
# ...

# %%
# !ls output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet
# Out:
# infer_cfg.yml  model.pdiparams	model.pdiparams.info  model.pdmodel

# %%
# !sed -i 's|Config(model_path, model_prefix)|Config(os.path.join(model_dir, "model.pdmodel"), os.path.join(model_dir, "model.pdiparams"))|' /content/PaddleDetection/deploy/python/infer.py

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet \
  --video_file=/content/short-video.mp4 \
  --device=CPU \
  --run_mode=paddle \
  --output_dir=/content/output/ \
  --save_images=True \
  --threshold=0.4
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# collect_trt_shape_info: False
# combine_method: nms
# cpu_threads: 1
# device: CPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: None
# match_metric: ios
# match_threshold: 0.6
# model_dir: output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet
# output_dir: /content/output/
# overlap_ratio: [0.25, 0.25]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet \
  --video_file=/content/video-2.mp4 \
  --device=CPU \
  --run_mode=paddle \
  --output_dir=/content/output/ \
  --save_images=True \
  --threshold=0.4
# Out:
# /usr/local/lib/python3.11/dist-packages/paddle/utils/cpp_extension/extension_utils.py:711: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# collect_trt_shape_info: False
# combine_method: nms
# cpu_threads: 1
# device: CPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: None
# match_metric: ios
# match_threshold: 0.6
# model_dir: output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet
# output_dir: /content/output/
# overlap_ratio: [0.25, 0.25]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# ...

# %%
# !python deploy/python/infer.py \
  --model_dir=output_inference/picodet_m_416_coco_lcnet/picodet_m_416_coco_lcnet \
  --video_file=/content/video-3.mp4 \
  --device=CPU \
  --run_mode=paddle \
  --output_dir=/content/output/ \
  --save_images=True \
  --threshold=0.4
# Out:
# Streaming output truncated to the last 5000 lines.
# detect frame: 4547
# Test iter 0
# class_id:9, confidence:0.4981, left_top:[150.34,860.08],right_bottom:[309.86,1013.15]
# class_id:55, confidence:0.5008, left_top:[0.61,0.24],right_bottom:[1375.29,1080.40]
# detect frame: 4548
# Test iter 0
# class_id:9, confidence:0.5237, left_top:[152.92,860.43],right_bottom:[307.03,1012.94]
# detect frame: 4549
# Test iter 0
# class_id:9, confidence:0.4064, left_top:[155.60,861.40],right_bottom:[304.96,1013.26]
# class_id:33, confidence:0.5232, left_top:[154.28,45.57],right_bottom:[314.43,227.17]
# detect frame: 4550
# Test iter 0
# class_id:33, confidence:0.5161, left_top:[162.29,45.12],right_bottom:[310.90,233.82]
# detect frame: 4551
# Test iter 0
# class_id:9, confidence:0.5197, left_top:[151.71,858.56],right_bottom:[311.65,1015.47]
# class_id:33, confidence:0.5005, left_top:[162.96,45.75],right_bottom:[311.37,232.65]
# detect frame: 4552
# Test iter 0
# ...
